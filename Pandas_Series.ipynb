# %% [markdown]
# ## Series Creation

# %%
import pandas as pd
import numpy as np

# %%
ice_cream = ['choc','vanila','straw','rum']
pd.Series(ice_cream)
# Out:
# 0      choc
# 1    vanila
# 2     straw
# 3       rum
# dtype: object

# %%
lottery = [1,4,5,6,78,7]
pd.Series(lottery)
# Out:
# 0     1
# 1     4
# 2     5
# 3     6
# 4    78
# 5     7
# dtype: int64

# %%
web = {'advark':'animal','banana':'friut','cyan':'a color'}
pd.Series(web)
# Out:
# advark     animal
# banana      friut
# cyan      a color
# dtype: object

# %% [markdown]
# ## INtro to Atrr

# %%
about_me = ['smart','intrelligent','osm','beast']
s = pd.Series(about_me)
s
# Out:
# 0           smart
# 1    intrelligent
# 2             osm
# 3           beast
# dtype: object

# %%
s.values
# Out:
# array(['smart', 'intrelligent', 'osm', 'beast'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## INtro to Method

# %%
price = [2.33,4.4,5.3,4.44,3.44]
s1 = pd.Series(price)
s1
# Out:
# 0    2.33
# 1    4.40
# 2    5.30
# 3    4.44
# 4    3.44
# dtype: float64

# %%
s1.sum()
# Out:
# 19.910000000000004

# %%
s1.product()
# Out:
# 829.90022016

# %%
s1.mean()
# Out:
# 3.9820000000000007

# %% [markdown]
# ## Parameter and Arguments

# %%
friuts = ["apple","grape","Orange","Berry"]
weekdays = ['monday','tuesday','thru','fri']
pd.Series(friuts,weekdays)
pd.Series(data=friuts,index=weekdays)
pd.Series(friuts,index=weekdays)
# Out:
# monday      apple
# tuesday     grape
# thru       Orange
# fri         Berry
# dtype: object

# %%
friuts = ["apple","grape","Orange","Berry","watermelon"]
weekdays = ['monday','tuesday','thru','fri','monday']
pd.Series(data=friuts,index=weekdays)
# Out:
# monday          apple
# tuesday         grape
# thru           Orange
# fri             Berry
# monday     watermelon
# dtype: object

# %% [markdown]
# ## Import series with read_csv

# %%
datetime = pd.read_csv('/home/nilesh/Desktop/yellow.csv',usecols=['tpep_pickup_datetime'],squeeze=True)

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',usecols=['Salary'],squeeze=True)

# %%
salary.head()
salary.head(10)
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# Name: Salary, dtype: float64

# %%
salary.tail()
salary.tail(7)
# Out:
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Python built in fun

# %%
len(salary)
len(datetime)
# Out:
# 8759874

# %%
type(datetime)
# Out:
# pandas.core.series.Series

# %%
dir(datetime)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
sorted(salary)
sorted(datetime)
# Out:
# ['2001-01-05 11:45:23',
#  '2002-12-31 23:01:55',
#  '2002-12-31 23:02:29',
#  '2002-12-31 23:03:13',
#  '2002-12-31 23:16:43',
#  '2002-12-31 23:47:02',
#  '2003-01-01 00:06:34',
#  '2003-01-01 00:25:20',
#  '2003-01-01 00:31:27',
#  '2003-01-01 01:12:28',
#  '2003-01-01 04:43:26',
#  '2008-12-31 18:30:07',
#  '2008-12-31 23:02:27',
#  '2008-12-31 23:05:28',
#  '2008-12-31 23:11:56',
#  '2008-12-31 23:15:43',
#  '2008-12-31 23:22:05',
#  '2008-12-31 23:30:14',
#  '2008-12-31 23:40:28',
#  '2008-12-31 23:45:58',
#  '2008-12-31 23:51:01',
#  '2008-12-31 23:56:44',
#  '2009-01-01 00:09:24',
#  '2009-01-01 00:16:26',
#  '2009-01-01 00:17:45',
#  '2009-01-01 00:30:00',
#  '2009-01-01 00:36:33',
#  '2009-01-01 00:48:49',
#  '2009-01-01 00:51:54',
#  '2009-01-01 01:03:33',
#  '2009-01-01 01:14:52',
#  '2009-01-01 01:37:21',
#  '2009-01-01 02:00:14',
#  '2009-01-01 03:32:24',
#  '2009-01-01 08:04:56',
#  '2009-01-01 10:05:05',
#  '2009-01-01 13:25:15',
#  '2009-01-01 15:20:10',
# ...

# %%
list(salary)
# Out:
# [39343.0,
#  46205.0,
#  37731.0,
#  43525.0,
#  39891.0,
#  56642.0,
#  60150.0,
#  54445.0,
#  64445.0,
#  57189.0,
#  63218.0,
#  55794.0,
#  56957.0,
#  57081.0,
#  61111.0,
#  67938.0,
#  66029.0,
#  83088.0,
#  81363.0,
#  93940.0,
#  91738.0,
#  98273.0,
#  101302.0,
#  113812.0,
#  109431.0,
#  105582.0,
#  116969.0,
#  112635.0,
#  122391.0,
#  121872.0]

# %%
dict(salary)
# Out:
# {0: 39343.0,
#  1: 46205.0,
#  2: 37731.0,
#  3: 43525.0,
#  4: 39891.0,
#  5: 56642.0,
#  6: 60150.0,
#  7: 54445.0,
#  8: 64445.0,
#  9: 57189.0,
#  10: 63218.0,
#  11: 55794.0,
#  12: 56957.0,
#  13: 57081.0,
#  14: 61111.0,
#  15: 67938.0,
#  16: 66029.0,
#  17: 83088.0,
#  18: 81363.0,
#  19: 93940.0,
#  20: 91738.0,
#  21: 98273.0,
#  22: 101302.0,
#  23: 113812.0,
#  24: 109431.0,
#  25: 105582.0,
#  26: 116969.0,
#  27: 112635.0,
#  28: 122391.0,
#  29: 121872.0}

# %%
max(salary)
# Out:
# 122391.0

# %%
min(salary)
# Out:
# 37731.0

# %% [markdown]
# ## More series Attri

# %%
salary.values
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
salary.dtype
# Out:
# dtype('float64')

# %%
salary.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
salary.is_unique
# Out:
# True

# %%
salary.ndim
# Out:
# 1

# %%
salary.shape
# Out:
# (30,)

# %%
datetime.shape
# Out:
# (8759874,)

# %%
salary.size
# Out:
# 30

# %%
salary.name ='Neil' #to change the name of the series

# %%
salary.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Neil, dtype: float64

# %% [markdown]
# ## the .sort values

# %%
salary.sort_values().head()
# Out:
# 2    37731.0
# 0    39343.0
# 4    39891.0
# 3    43525.0
# 1    46205.0
# Name: Neil, dtype: float64

# %%
salary.sort_values(ascending=False).tail()
# Out:
# 1    46205.0
# 3    43525.0
# 4    39891.0
# 0    39343.0
# 2    37731.0
# Name: Neil, dtype: float64

# %% [markdown]
# ## Inplace Parameters

# %%
salary.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Neil, dtype: float64

# %%
salary = salary.sort_values()

# %%
salary.sort_index()
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Neil, dtype: float64

# %%
salary.sort_values(ascending=False,inplace=True) # permently modify the variable

# %%
salary.head()
# Out:
# 28    122391.0
# 29    121872.0
# 26    116969.0
# 23    113812.0
# 27    112635.0
# Name: Neil, dtype: float64

# %% [markdown]
# ## sort index

# %%
salary.sort_values(inplace=True)
salary.head()
# Out:
# 2    37731.0
# 0    39343.0
# 4    39891.0
# 3    43525.0
# 1    46205.0
# Name: Neil, dtype: float64

# %%
salary.sort_index(ascending=True)
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Neil, dtype: float64

# %%
salary.sort_index(ascending=False)
# Out:
# 29    121872.0
# 28    122391.0
# 27    112635.0
# 26    116969.0
# 25    105582.0
# 24    109431.0
# 23    113812.0
# 22    101302.0
# 21     98273.0
# 20     91738.0
# 19     93940.0
# 18     81363.0
# 17     83088.0
# 16     66029.0
# 15     67938.0
# 14     61111.0
# 13     57081.0
# 12     56957.0
# 11     55794.0
# 10     63218.0
# 9      57189.0
# 8      64445.0
# 7      54445.0
# 6      60150.0
# 5      56642.0
# 4      39891.0
# 3      43525.0
# 2      37731.0
# 1      46205.0
# 0      39343.0
# Name: Neil, dtype: float64

# %% [markdown]
# ## Python in keywords

# %%
100 in [1,2,3,4,5,65]
# Out:
# False

# %%
10 in salary.index
# Out:
# True

# %%
43525 in salary.values
# Out:
# True

# %% [markdown]
# ## Extract values by the series index

# %%
salary[12]
# Out:
# 56957.0

# %%
salary[[12,13,14]]
# Out:
# 12    56957.0
# 13    57081.0
# 14    61111.0
# Name: Neil, dtype: float64

# %%
salary[5:10]
# Out:
# 7     54445.0
# 11    55794.0
# 5     56642.0
# 12    56957.0
# 13    57081.0
# Name: Neil, dtype: float64

# %%
salary[:15]
# Out:
# 2     37731.0
# 0     39343.0
# 4     39891.0
# 3     43525.0
# 1     46205.0
# 7     54445.0
# 11    55794.0
# 5     56642.0
# 12    56957.0
# 13    57081.0
# 9     57189.0
# 6     60150.0
# 14    61111.0
# 10    63218.0
# 8     64445.0
# Name: Neil, dtype: float64

# %%
salary[-5:]
# Out:
# 27    112635.0
# 23    113812.0
# 26    116969.0
# 29    121872.0
# 28    122391.0
# Name: Neil, dtype: float64

# %%
salary[-5:-2]
# Out:
# 27    112635.0
# 23    113812.0
# 26    116969.0
# Name: Neil, dtype: float64

# %% [markdown]
# ## extract values by index label

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',index_col='Salary',squeeze=True)

# %%
salary.head()
# Out:
# Salary
# 39343.0    1.1
# 46205.0    1.3
# 37731.0    1.5
# 43525.0    2.0
# 39891.0    2.2
# Name: YearsExperience, dtype: float64

# %%
salary[39343]
# Out:
# 1.1

# %%
salary[[39343,46205]]
# Out:
# Salary
# 39343    1.1
# 46205    1.3
# Name: YearsExperience, dtype: float64

# %%
salary[[39343,0]] # if index values is not present then it will show NaN
# Out:
# /home/nilesh/.local/lib/python2.7/site-packages/pandas/core/series.py:942: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# Salary
# 39343    1.1
# 0        NaN
# Name: YearsExperience, dtype: float64

# %%
salary.name = 'EXp'

# %%
salary
# Out:
# Salary
# 39343.0      1.1
# 46205.0      1.3
# 37731.0      1.5
# 43525.0      2.0
# 39891.0      2.2
# 56642.0      2.9
# 60150.0      3.0
# 54445.0      3.2
# 64445.0      3.2
# 57189.0      3.7
# 63218.0      3.9
# 55794.0      4.0
# 56957.0      4.0
# 57081.0      4.1
# 61111.0      4.5
# 67938.0      4.9
# 66029.0      5.1
# 83088.0      5.3
# 81363.0      5.9
# 93940.0      6.0
# 91738.0      6.8
# 98273.0      7.1
# 101302.0     7.9
# 113812.0     8.2
# 109431.0     8.7
# 105582.0     9.0
# 116969.0     9.5
# 112635.0     9.6
# 122391.0    10.3
# 121872.0    10.5
# Name: EXp, dtype: float64

# %% [markdown]
# # .get method

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',index_col='Salary',squeeze=True)
salary.sort_index(inplace=True)
salary.head()
# Out:
# Salary
# 37731.0    1.5
# 39343.0    1.1
# 39891.0    2.2
# 43525.0    2.0
# 46205.0    1.3
# Name: YearsExperience, dtype: float64

# %%
salary.get(37731)
# Out:
# 1.5

# %%
salary.get([37731,39343])
# Out:
# Salary
# 37731    1.5
# 39343    1.1
# Name: YearsExperience, dtype: float64

# %%
salary.get(key=876,default='Not Present')
# Out:
# 'Not Present'

# %%
salary.get(key=[39343,767]) #if values not preasent then return NaN
# Out:
# Salary
# 39343    1.1
# 767      NaN
# Name: YearsExperience, dtype: float64

# %% [markdown]
# ## Math Methods available in series

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',usecols=['Salary'],squeeze=True)

# %%
salary.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
salary.count()
# Out:
# 30

# %%
len(salary)
# Out:
# 30

# %%
salary.sum()
# Out:
# 2280090.0

# %%
salary.mean()
# Out:
# 76003.0

# %%
salary.sum()/salary.count()
# Out:
# 76003.0

# %%
salary.std()
# Out:
# 27414.4297845823

# %%
salary.min()
# Out:
# 37731.0

# %%
salary.median()
# Out:
# 65237.0

# %%
salary.mode()
# Out:
# 0      37731.0
# 1      39343.0
# 2      39891.0
# 3      43525.0
# 4      46205.0
# 5      54445.0
# 6      55794.0
# 7      56642.0
# 8      56957.0
# 9      57081.0
# 10     57189.0
# 11     60150.0
# 12     61111.0
# 13     63218.0
# 14     64445.0
# 15     66029.0
# 16     67938.0
# 17     81363.0
# 18     83088.0
# 19     91738.0
# 20     93940.0
# 21     98273.0
# 22    101302.0
# 23    105582.0
# 24    109431.0
# 25    112635.0
# 26    113812.0
# 27    116969.0
# 28    121872.0
# 29    122391.0
# dtype: float64

# %%
salary.describe()
# Out:
# count        30.000000
# mean      76003.000000
# std       27414.429785
# min       37731.000000
# 25%       56720.750000
# 50%       65237.000000
# 75%      100544.750000
# max      122391.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ## Index max and index min methods

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',usecols=['Salary'],squeeze=True)

# %%
salary.head(5)
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
salary.idxmax() # give index of that values which is max
# Out:
# 28

# %%
salary.idxmin() # give index of that values which is min
# Out:
# 2

# %%
salary[28]
# Out:
# 122391.0

# %%
salary[2]
# Out:
# 37731.0

# %%
salary.min()
# Out:
# 37731.0

# %%
salary.max()
# Out:
# 122391.0

# %%
salary[salary.idxmax()]
# Out:
# 122391.0

# %%
salary[salary.idxmin()]
# Out:
# 37731.0

# %% [markdown]
# ## .value_count method

# %%
salary = pd.read_csv('/home/nilesh/Desktop/yellow.csv',usecols=['fare_amount'],squeeze=True)
salary.head()
# Out:
# 0     4.5
# 1    14.0
# 2     6.0
# 3    33.5
# 4    12.5
# Name: fare_amount, dtype: float64

# %%
salary.value_counts().head(5)
# Out:
# 6.0    473234
# 5.5    465176
# 6.5    461927
# 7.0    446376
# 5.0    433249
# Name: fare_amount, dtype: int64

# %%
salary.value_counts().sum()
# Out:
# 8759874

# %%
salary.count()
# Out:
# 8759874

# %%
salary.value_counts(ascending=True)
# Out:
#  30.35          1
#  980.06         1
#  286.60         1
#  27.28          1
#  2.52           1
#  384.60         1
#  3.73           1
# -69.00          1
#  162.80         1
#  167.20         1
#  189.70         1
#  138.20         1
#  139.20         1
#  143.20         1
#  128.80         1
#  135.55         1
#  29.16          1
#  153.20         1
#  55.20          1
#  55.70          1
#  56.30          1
#  57.80          1
# -16.80          1
#  57.20          1
#  63.55          1
#  63.70          1
#  60.55          1
#  60.30          1
#  61.05          1
#  61.30          1
#             ...
#  17.50      68324
#  17.00      75256
#  16.50      80540
#  16.00      89317
#  15.50      96926
#  15.00     106898
#  14.50     116526
#  14.00     129760
#  3.50      133043
#  13.50     142080
#  13.00     157868
#  12.50     175196
#  52.00     180719
#  12.00     193830
#  11.50     212729
#  11.00     236136
#  4.00      256294
#  10.50     259848
#  10.00     289305
# ...

# %% [markdown]
# ## .apply method

# %%
salary.head()
# Out:
# 0     4.5
# 1    14.0
# 2     6.0
# 3    33.5
# 4    12.5
# Name: fare_amount, dtype: float64

# %%
def classify(num):
    if num<5:
        return 'ok'
    elif num>=5 and num <15:
        return 'Satisfy'
    else:
        return 'hell'

# %%
salary.apply(classify)
# Out:
# 0               ok
# 1          Satisfy
# 2          Satisfy
# 3             hell
# 4          Satisfy
# 5               ok
# 6          Satisfy
# 7               ok
# 8          Satisfy
# 9          Satisfy
# 10         Satisfy
# 11            hell
# 12         Satisfy
# 13         Satisfy
# 14         Satisfy
# 15            hell
# 16            hell
# 17              ok
# 18            hell
# 19         Satisfy
# 20         Satisfy
# 21         Satisfy
# 22         Satisfy
# 23            hell
# 24         Satisfy
# 25              ok
# 26            hell
# 27              ok
# 28         Satisfy
# 29         Satisfy
#             ...
# 8759844         ok
# 8759845       hell
# 8759846    Satisfy
# 8759847    Satisfy
# 8759848    Satisfy
# 8759849    Satisfy
# 8759850    Satisfy
# 8759851       hell
# 8759852       hell
# 8759853       hell
# 8759854    Satisfy
# 8759855    Satisfy
# 8759856       hell
# 8759857    Satisfy
# 8759858         ok
# 8759859       hell
# ...

# %%
salary.head()
# Out:
# 0     4.5
# 1    14.0
# 2     6.0
# 3    33.5
# 4    12.5
# Name: fare_amount, dtype: float64

# %%
salary.apply(lambda sp:sp + 1)
# Out:
# 0           5.5
# 1          15.0
# 2           7.0
# 3          34.5
# 4          13.5
# 5           5.5
# 6          10.0
# 7           5.0
# 8           6.5
# 9           6.5
# 10          6.5
# 11         17.5
# 12          6.5
# 13          8.5
# 14         11.0
# 15         20.0
# 16         26.5
# 17          5.5
# 18         36.0
# 19          7.0
# 20         14.0
# 21         10.5
# 22         15.5
# 23         19.0
# 24         13.0
# 25          5.5
# 26         17.0
# 27          5.0
# 28          7.0
# 29          8.5
#            ...
# 8759844     5.5
# 8759845    19.0
# 8759846    14.5
# 8759847    11.5
# 8759848     9.5
# 8759849    15.5
# 8759850     7.5
# 8759851    19.5
# 8759852    22.5
# 8759853    19.0
# 8759854    15.5
# 8759855     6.0
# 8759856    35.5
# 8759857     7.5
# 8759858     5.5
# 8759859    37.5
# 8759860    43.0
# 8759861     5.0
# 8759862     8.5
# 8759863    13.5
# 8759864    11.0
# 8759865     5.5
# 8759866     7.0
# 8759867     9.5
# ...

# %% [markdown]
# ## the MAp Method

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',usecols=['Salary'],squeeze=True)
salary.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
exp = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',index_col='Salary',squeeze=True)
exp.head()
# Out:
# Salary
# 39343.0    1.1
# 46205.0    1.3
# 37731.0    1.5
# 43525.0    2.0
# 39891.0    2.2
# Name: YearsExperience, dtype: float64

# %%
salary.map(exp) # in this function put the index types inside the map and apply map on the series
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: Salary, dtype: float64

# %%
salary = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',usecols=['Salary'],squeeze=True)
exp = pd.read_csv('/home/nilesh/Downloads/P14-Simple-Linear-Regression/Simple_Linear_Regression/data.csv',index_col='Salary',squeeze=True).to_dict()

# %%
salary.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
exp
# Out:
# {37731.0: 1.5,
#  39343.0: 1.1,
#  39891.0: 2.2,
#  43525.0: 2.0,
#  46205.0: 1.3,
#  54445.0: 3.2,
#  55794.0: 4.0,
#  56642.0: 2.9,
#  56957.0: 4.0,
#  57081.0: 4.1,
#  57189.0: 3.7,
#  60150.0: 3.0,
#  61111.0: 4.5,
#  63218.0: 3.9,
#  64445.0: 3.2,
#  66029.0: 5.1,
#  67938.0: 4.9,
#  81363.0: 5.9,
#  83088.0: 5.3,
#  91738.0: 6.8,
#  93940.0: 6.0,
#  98273.0: 7.1,
#  101302.0: 7.9,
#  105582.0: 9.0,
#  109431.0: 8.7,
#  112635.0: 9.6,
#  113812.0: 8.2,
#  116969.0: 9.5,
#  121872.0: 10.5,
#  122391.0: 10.3}

# %%
salary.map(exp)
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: Salary, dtype: float64
